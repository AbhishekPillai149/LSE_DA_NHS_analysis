# %% [markdown]
# ### LSE Data Analytics Online Career Accelerator
#
# # Course 2: Data Analytics using Python

# %% [markdown]
# ## Assignment: Diagnostic Analysis using Python
#
# You’ll be working with real-world data to address a problem faced by the National Health Service (NHS). The analysis will require you to utilise Python to explore the available data, create visualisations to identify trends, and extract meaningful insights to inform decision-making.

# %% [markdown]
# ### A note for students using this template
# This Jupyter Notebook is a template you can use to complete the Course 2 assignment: Diagnostic Analysis using Python.
#
# Keep in mind:
# - You are **not required** to use this template to complete the assignment.
# - If you decide to use this template for your assignment, make a copy of the notebook and save it using the assignment naming convention: **LastName_FirstName_DA201_Assignment_Notebook.ipynb**.
# - The workflow suggested in this template follows the Assignment Activities throughout the course.
# - Refer to the guidance on the Assignment Activity pages for specific details.
# - The markup and comments in this template identify the key elements you need to complete before submitting the assignment.
# - Make this notebook your own by adding your process notes and rationale using markdown, add links, screenshots, or images to support your analysis, refine or clarify the comments, and change the workflow to suit your process.
# - All elements should be functional and visible in your Notebook.
# - Be sure to push your notebook to GitHub after completing each Assignment Activity.
#
#  > ***Markdown*** Remember to change cell types to `Markdown`. You can review [Markdown basics](https://docs.github.com/en/get-started/writing-on-github/getting-started-with-writing-and-formatting-on-github/basic-writing-and-formatting-syntax) to find out how to add formatted text, links, and images to your notebook.

# %% [markdown]
# #

# %% [markdown]
# # Assignment Activity 1: Prepare Your Github Repository

# %% [markdown]
# ### Insert proof of your GitHub repository. This can be a link or screenshot showing your repo.

# %%
# My GitHub repository.

# %% [markdown]
# https://github.com/AbhishekPillai149/LSE_DA_NHS_analysis.git

# %% [markdown]
# #

# %% [markdown]
# # Assignment Activity 2 : Import And Explore The Data

# %% [markdown]
# ### Prepare your workstation

# %%
# Import the necessary libraries.
import pandas as pd
import numpy as np

# Optional - Ignore warnings.
import warnings
warnings.filterwarnings('ignore')

# %%
# Import the actual_duration.csv data set as 'ad'.
ad = pd.read_csv('actual_duration.csv')

# View the 'ad' DataFrame.
ad
# Out:
#        sub_icb_location_code sub_icb_location_ons_code  \
# 0                        00L                 E38000130
# 1                        00L                 E38000130
# 2                        00L                 E38000130
# 3                        00L                 E38000130
# 4                        00L                 E38000130
# ...                      ...                       ...
# 137788                 X2C4Y                 E38000254
# 137789                 X2C4Y                 E38000254
# 137790                 X2C4Y                 E38000254
# 137791                 X2C4Y                 E38000254
# 137792                 X2C4Y                 E38000254
#
#                              sub_icb_location_name icb_ons_code  \
# 0       NHS North East and North Cumbria ICB - 00L    E54000050
# 1       NHS North East and North Cumbria ICB - 00L    E54000050
# 2       NHS North East and North Cumbria ICB - 00L    E54000050
# ...

# %%
# Sense check 'ad' by obtaining its first few rows
ad.head()
# Out:
#   sub_icb_location_code sub_icb_location_ons_code  \
# 0                   00L                 E38000130
# 1                   00L                 E38000130
# 2                   00L                 E38000130
# 3                   00L                 E38000130
# 4                   00L                 E38000130
#
#                         sub_icb_location_name icb_ons_code region_ons_code  \
# 0  NHS North East and North Cumbria ICB - 00L    E54000050       E40000012
# 1  NHS North East and North Cumbria ICB - 00L    E54000050       E40000012
# 2  NHS North East and North Cumbria ICB - 00L    E54000050       E40000012
# 3  NHS North East and North Cumbria ICB - 00L    E54000050       E40000012
# 4  NHS North East and North Cumbria ICB - 00L    E54000050       E40000012
#
#   appointment_date         actual_duration  count_of_appointments
# 0        01-Dec-21           31-60 Minutes                    364
# 1        01-Dec-21           21-30 Minutes                    619
# ...

# %%
# Sense check 'ad' by obtaining its shape
ad.shape
# Out:
# (137793, 8)

# %%
# Sense check 'ad' by obtaining the column names of the DataFrame
ad.columns
# Out:
# Index(['sub_icb_location_code', 'sub_icb_location_ons_code',
#        'sub_icb_location_name', 'icb_ons_code', 'region_ons_code',
#        'appointment_date', 'actual_duration', 'count_of_appointments'],
#       dtype='object')

# %%
# Sense check 'ad' by obtaining the data types of each of its columns
ad.dtypes
# Out:
# sub_icb_location_code        object
# sub_icb_location_ons_code    object
# sub_icb_location_name        object
# icb_ons_code                 object
# region_ons_code              object
# appointment_date             object
# actual_duration              object
# count_of_appointments         int64
# dtype: object

# %%
# Determine whether there are missing values in 'ad'.
print(ad.isnull().sum())
# Out:
# sub_icb_location_code        0
# sub_icb_location_ons_code    0
# sub_icb_location_name        0
# icb_ons_code                 0
# region_ons_code              0
# appointment_date             0
# actual_duration              0
# count_of_appointments        0
# dtype: int64

# %%
# Determine the metadata of 'ad'.
ad.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 137793 entries, 0 to 137792
# Data columns (total 8 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   sub_icb_location_code      137793 non-null  object
#  1   sub_icb_location_ons_code  137793 non-null  object
#  2   sub_icb_location_name      137793 non-null  object
#  3   icb_ons_code               137793 non-null  object
#  4   region_ons_code            137793 non-null  object
#  5   appointment_date           137793 non-null  object
#  6   actual_duration            137793 non-null  object
#  7   count_of_appointments      137793 non-null  int64
# dtypes: int64(1), object(7)
# memory usage: 8.4+ MB

# %%
# Determine the descriptive statistics of 'ad'.
ad.describe()
# Out:
#        count_of_appointments
# count          137793.000000
# mean             1219.080011
# std              1546.902956
# min                 1.000000
# 25%               194.000000
# 50%               696.000000
# 75%              1621.000000
# max             15400.000000

# %%
# Import the appointments_regional.csv data set as 'ar'.
ar = pd.read_csv('appointments_regional.csv')

# View the 'ar' DataFrame.
ar
# Out:
#        icb_ons_code appointment_month appointment_status hcp_type  \
# 0         E54000034           2020-01           Attended       GP
# 1         E54000034           2020-01           Attended       GP
# 2         E54000034           2020-01           Attended       GP
# 3         E54000034           2020-01           Attended       GP
# 4         E54000034           2020-01           Attended       GP
# ...             ...               ...                ...      ...
# 596816    E54000050           2022-06            Unknown  Unknown
# 596817    E54000050           2022-06            Unknown  Unknown
# 596818    E54000050           2022-06            Unknown  Unknown
# 596819    E54000050           2022-06            Unknown  Unknown
# 596820    E54000050           2022-06            Unknown  Unknown
#
#        appointment_mode time_between_book_and_appointment  \
# 0          Face-to-Face                             1 Day
# ...

# %%
# Sense check 'ar' by obtaining its first few rows
ar.head()
# Out:
#   icb_ons_code appointment_month appointment_status hcp_type appointment_mode  \
# 0    E54000034           2020-01           Attended       GP     Face-to-Face
# 1    E54000034           2020-01           Attended       GP     Face-to-Face
# 2    E54000034           2020-01           Attended       GP     Face-to-Face
# 3    E54000034           2020-01           Attended       GP     Face-to-Face
# 4    E54000034           2020-01           Attended       GP     Face-to-Face
#
#   time_between_book_and_appointment  count_of_appointments
# 0                             1 Day                   8107
# 1                    15  to 21 Days                   6791
# 2                       2 to 7 Days                  20686
# 3                    22  to 28 Days                   4268
# 4                     8  to 14 Days                  11971

# %%
# Sense check 'ar' by obtaining its shape
ar.shape
# Out:
# (596821, 7)

# %%
# Sense check 'ar' by obtaining the column names of the dataframe
ar.columns
# Out:
# Index(['icb_ons_code', 'appointment_month', 'appointment_status', 'hcp_type',
#        'appointment_mode', 'time_between_book_and_appointment',
#        'count_of_appointments'],
#       dtype='object')

# %%
# Sense check 'ar' by obtaining the data types of each of its columns
ar.dtypes
# Out:
# icb_ons_code                         object
# appointment_month                    object
# appointment_status                   object
# hcp_type                             object
# appointment_mode                     object
# time_between_book_and_appointment    object
# count_of_appointments                 int64
# dtype: object

# %%
# Determine whether there are missing values in 'ar'
print(ar.isnull().sum())
# Out:
# icb_ons_code                         0
# appointment_month                    0
# appointment_status                   0
# hcp_type                             0
# appointment_mode                     0
# time_between_book_and_appointment    0
# count_of_appointments                0
# dtype: int64

# %%
# Determine the metadata of 'ar'.
ar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 596821 entries, 0 to 596820
# Data columns (total 7 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   icb_ons_code                       596821 non-null  object
#  1   appointment_month                  596821 non-null  object
#  2   appointment_status                 596821 non-null  object
#  3   hcp_type                           596821 non-null  object
#  4   appointment_mode                   596821 non-null  object
#  5   time_between_book_and_appointment  596821 non-null  object
#  6   count_of_appointments              596821 non-null  int64
# dtypes: int64(1), object(6)
# memory usage: 31.9+ MB

# %%
# Determine the descriptive statistics of 'ar'.
ar.describe()
# Out:
#        count_of_appointments
# count          596821.000000
# mean             1244.601857
# std              5856.887042
# min                 1.000000
# 25%                 7.000000
# 50%                47.000000
# 75%               308.000000
# max            211265.000000

# %%
# Import and sense-check the national_categories.xlsx data set as 'nc'.
nc = pd.read_excel('national_categories.xlsx')

# View the 'nc' DataFrame.
nc
# Out:
#        appointment_date icb_ons_code  \
# 0            2021-08-02    E54000050
# 1            2021-08-02    E54000050
# 2            2021-08-02    E54000050
# 3            2021-08-02    E54000050
# 4            2021-08-02    E54000050
# ...                 ...          ...
# 817389       2022-06-30    E54000054
# 817390       2022-06-30    E54000054
# 817391       2022-06-30    E54000054
# 817392       2022-06-30    E54000054
# 817393       2022-06-30    E54000054
#
#                              sub_icb_location_name            service_setting  \
# 0       NHS North East and North Cumbria ICB - 00L       Primary Care Network
# 1       NHS North East and North Cumbria ICB - 00L                      Other
# 2       NHS North East and North Cumbria ICB - 00L           General Practice
# 3       NHS North East and North Cumbria ICB - 00L           General Practice
# 4       NHS North East and North Cumbria ICB - 00L           General Practice
# ...

# %%
# Sense check 'nc' by obtaining its first few rows
nc.head()
# Out:
#   appointment_date icb_ons_code                       sub_icb_location_name  \
# 0       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
# 1       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
# 2       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
# 3       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
# 4       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
#
#         service_setting            context_type  \
# 0  Primary Care Network  Care Related Encounter
# 1                 Other  Care Related Encounter
# 2      General Practice  Care Related Encounter
# 3      General Practice  Care Related Encounter
# 4      General Practice  Care Related Encounter
#
#                         national_category  count_of_appointments  \
# 0  Patient contact during Care Home Round                      3
# 1                         Planned Clinics                      7
# ...

# %%
# Sense check 'nc' by obtaining its shape
nc.shape
# Out:
# (817394, 8)

# %%
# Sense check 'nc' by obtaining the column names of the DataFrame
nc.columns
# Out:
# Index(['appointment_date', 'icb_ons_code', 'sub_icb_location_name',
#        'service_setting', 'context_type', 'national_category',
#        'count_of_appointments', 'appointment_month'],
#       dtype='object')

# %%
# Sense check 'nc' by obtaining the data types of its columns names 
nc.dtypes
# Out:
# appointment_date         datetime64[ns]
# icb_ons_code                     object
# sub_icb_location_name            object
# service_setting                  object
# context_type                     object
# national_category                object
# count_of_appointments             int64
# appointment_month                object
# dtype: object

# %%
# Determine whether there are missing values in 'nc'
print(nc.isnull().sum())
# Out:
# appointment_date         0
# icb_ons_code             0
# sub_icb_location_name    0
# service_setting          0
# context_type             0
# national_category        0
# count_of_appointments    0
# appointment_month        0
# dtype: int64

# %%
# Determine the metadata of 'nc'.
nc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 817394 entries, 0 to 817393
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   appointment_date       817394 non-null  datetime64[ns]
#  1   icb_ons_code           817394 non-null  object
#  2   sub_icb_location_name  817394 non-null  object
#  3   service_setting        817394 non-null  object
#  4   context_type           817394 non-null  object
#  5   national_category      817394 non-null  object
#  6   count_of_appointments  817394 non-null  int64
#  7   appointment_month      817394 non-null  object
# dtypes: datetime64[ns](1), int64(1), object(6)
# memory usage: 49.9+ MB

# %%
# Determine the descriptive statistics of 'nc'.
nc.describe()
# Out:
#        count_of_appointments
# count          817394.000000
# mean              362.183684
# std              1084.576600
# min                 1.000000
# 25%                 7.000000
# 50%                25.000000
# 75%               128.000000
# max             16590.000000

# %% [markdown]
# ### Explore the data set

# %% [markdown]
# **Question 1:** How many locations are there in the data set?

# %%
# Determine the number of locations.
Locations_List_nc = nc['sub_icb_location_name'].value_counts(ascending = False)
Loc_Count_nc = Locations_List_nc.count()

# View Output.
Loc_Count_nc
# Out:
# 106

# %%
# Cross - Check Previous Value with the ad data frame
Locations_List_ad = ad['sub_icb_location_name'].value_counts(ascending = False)
Loc_Count_ad = Locations_List_ad.count()

# Check that the number of locations obtained from ad is the same as nc
if Loc_Count_ad == Loc_Count_nc:
    print('CONSTANT')
# Out:
# CONSTANT

# %% [markdown]
# **Question 2:** What are the five locations with the highest number of records?

# %%
# Determine the top five locations based on record count.
Top_5_Loc_nc = Locations_List_nc.head(5)

# View Output.
Top_5_Loc_nc
# Out:
# NHS North West London ICB - W2U3Z              13007
# NHS Kent and Medway ICB - 91Q                  12637
# NHS Devon ICB - 15N                            12526
# NHS Hampshire and Isle Of Wight ICB - D9Y0V    12171
# NHS North East London ICB - A3A8R              11837
# Name: sub_icb_location_name, dtype: int64

# %% [markdown]
# **Question 3:** How many service settings, context types, national categories, and appointment statuses are there?

# %%
# Determine the number of service settings.
Serv_Sett = nc['service_setting'].value_counts(ascending=True)
Service_Number = Serv_Sett.count()

# Determine the number of context types.
Con_Typ = nc['context_type'].value_counts(ascending=True)
Context_Number = Con_Typ.count()

# Determine the number of national categories.
Nat_Cat = nc['national_category'].value_counts(ascending=True)
National_Number = Nat_Cat.count()

# Determine the number of appointment status.
Appt_Stat = ar['appointment_status'].value_counts(ascending=True)
Appt_Number = Appt_Stat.count()

# View Ouput
print('a) Number of Service Settings', Service_Number)
print('b) Number of Context Types', Context_Number)
print('c) Number of National Categories', National_Number)
print('d) Number of Appointment Statuses', Appt_Number)
# Out:
# a) Number of Service Settings 5
# b) Number of Context Types 3
# c) Number of National Categories 18
# d) Number of Appointment Statuses 3

# %% [markdown]
# #

# %% [markdown]
# # Assignment Activity 3: Analyse The Data

# %% [markdown]
# ### Continue to explore the data and search for answers to more specific questions posed by the NHS.

# %% [markdown]
# **Question 1:** Between what dates were appointments scheduled?

# %%
# View the first five rows of appointment_date for the 'ad' DataFrame to determine the date format.
ad.head(5)
# Out:
#   sub_icb_location_code sub_icb_location_ons_code  \
# 0                   00L                 E38000130
# 1                   00L                 E38000130
# 2                   00L                 E38000130
# 3                   00L                 E38000130
# 4                   00L                 E38000130
#
#                         sub_icb_location_name icb_ons_code region_ons_code  \
# 0  NHS North East and North Cumbria ICB - 00L    E54000050       E40000012
# 1  NHS North East and North Cumbria ICB - 00L    E54000050       E40000012
# 2  NHS North East and North Cumbria ICB - 00L    E54000050       E40000012
# 3  NHS North East and North Cumbria ICB - 00L    E54000050       E40000012
# 4  NHS North East and North Cumbria ICB - 00L    E54000050       E40000012
#
#   appointment_date         actual_duration  count_of_appointments
# 0        01-Dec-21           31-60 Minutes                    364
# 1        01-Dec-21           21-30 Minutes                    619
# ...

# %%
# View the first five rows of appointment_date for the 'nc' DataFrame to determine the date format.
nc.head(5)
# Out:
#   appointment_date icb_ons_code                       sub_icb_location_name  \
# 0       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
# 1       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
# 2       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
# 3       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
# 4       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
#
#         service_setting            context_type  \
# 0  Primary Care Network  Care Related Encounter
# 1                 Other  Care Related Encounter
# 2      General Practice  Care Related Encounter
# 3      General Practice  Care Related Encounter
# 4      General Practice  Care Related Encounter
#
#                         national_category  count_of_appointments  \
# 0  Patient contact during Care Home Round                      3
# 1                         Planned Clinics                      7
# ...

# %%
# Change the date format of ad['appointment_date'].
ad['appointment_date'] = pd.to_datetime(ad['appointment_date'])

# View the 'ad' DateFrame.
ad
# Out:
#        sub_icb_location_code sub_icb_location_ons_code  \
# 0                        00L                 E38000130
# 1                        00L                 E38000130
# 2                        00L                 E38000130
# 3                        00L                 E38000130
# 4                        00L                 E38000130
# ...                      ...                       ...
# 137788                 X2C4Y                 E38000254
# 137789                 X2C4Y                 E38000254
# 137790                 X2C4Y                 E38000254
# 137791                 X2C4Y                 E38000254
# 137792                 X2C4Y                 E38000254
#
#                              sub_icb_location_name icb_ons_code  \
# 0       NHS North East and North Cumbria ICB - 00L    E54000050
# 1       NHS North East and North Cumbria ICB - 00L    E54000050
# 2       NHS North East and North Cumbria ICB - 00L    E54000050
# ...

# %%
# Change the date format of nc['appointment_date'].
nc['appointment_date'] = pd.to_datetime(nc['appointment_date'])

# View the 'nc' DateFrame.
nc
# Out:
#        appointment_date icb_ons_code  \
# 0            2021-08-02    E54000050
# 1            2021-08-02    E54000050
# 2            2021-08-02    E54000050
# 3            2021-08-02    E54000050
# 4            2021-08-02    E54000050
# ...                 ...          ...
# 817389       2022-06-30    E54000054
# 817390       2022-06-30    E54000054
# 817391       2022-06-30    E54000054
# 817392       2022-06-30    E54000054
# 817393       2022-06-30    E54000054
#
#                              sub_icb_location_name            service_setting  \
# 0       NHS North East and North Cumbria ICB - 00L       Primary Care Network
# 1       NHS North East and North Cumbria ICB - 00L                      Other
# 2       NHS North East and North Cumbria ICB - 00L           General Practice
# 3       NHS North East and North Cumbria ICB - 00L           General Practice
# 4       NHS North East and North Cumbria ICB - 00L           General Practice
# ...

# %%
# Determine the minimum and maximum dates in the 'ad' DataFrame.
# Use appropriate docstrings.pri
print('ad min:',ad['appointment_date'].min())
print('ad max:',ad['appointment_date'].max())
# Out:
# ad min: 2021-12-01 00:00:00
# ad max: 2022-06-30 00:00:00

# %%
# Determine the minimum and maximum dates in the nc DataFrame.
# Use appropriate docstrings.
print('nc min:',nc['appointment_date'].min())
print('nc max:',nc['appointment_date'].max())
# Out:
# nc min: 2021-08-01 00:00:00
# nc max: 2022-06-30 00:00:00

# %% [markdown]
# **Question 2:** Which service setting was the most popular for NHS North West London from 1 January to 1 June 2022?

# %%
# For each of these service settings, determine the number of records available for the period and the location. 
nc_sub = nc[['service_setting','sub_icb_location_name','appointment_date']]
nc_sub_2 = nc_sub.loc[nc_sub['sub_icb_location_name']
                      =='NHS North West London ICB - W2U3Z']
nc_sub_3 = nc_sub_2[(nc_sub_2['appointment_date'] >= '2022-01-01')                                    
                    & (nc_sub_2['appointment_date'] <= '2022-06-01')]

serv_sett_total_count = nc_sub_3['service_setting'].value_counts()

# View the output.
serv_sett_total_count
# Out:
# General Practice             2104
# Other                        1318
# Primary Care Network         1272
# Extended Access Provision    1090
# Unmapped                      152
# Name: service_setting, dtype: int64

# %% [markdown]
# **Question 3:** Which month had the highest number of appointments?

# %%
# Number of appointments per month == sum of count_of_appointments by month.
# Use the groupby() and sort_values() functions.
monthly_appts_nc = nc.groupby('appointment_month')[['count_of_appointments']]\
                                                   .sum().sort_values('count_of_appointments').reset_index()

# View Output.
monthly_appts_nc
# Out:
#    appointment_month  count_of_appointments
# 0            2021-08               23852171
# 1            2022-04               23913060
# 2            2021-12               25140776
# 3            2022-02               25355260
# 4            2022-01               25635474
# 5            2022-06               25828078
# 6            2022-05               27495508
# 7            2021-09               28522501
# 8            2022-03               29595038
# 9            2021-10               30303834
# 10           2021-11               30405070

# %% [markdown]
# November has the highest number of appointments

# %% [markdown]
# **Question 4:** What was the total number of records per month?

# %%
# Total number of records per month.
total_rec = nc['appointment_month'].value_counts(normalize=False, sort=True, ascending=False, dropna=True)
total_rec_data = pd.DataFrame(total_rec).reset_index()

# Rename the collumns
total_rec_data.rename(columns={'index': 'appt_month', 'appointment_month':'Record Count'}, inplace=True)

# View Output.
total_rec_data
# Out:
#    appt_month  Record Count
# 0     2022-03         82822
# 1     2021-11         77652
# 2     2022-05         77425
# 3     2021-09         74922
# 4     2022-06         74168
# 5     2021-10         74078
# 6     2021-12         72651
# 7     2022-01         71896
# 8     2022-02         71769
# 9     2022-04         70012
# 10    2021-08         69999

# %% [markdown]
# #

# %% [markdown]
# # Assignment activity 4

# %% [markdown]
# ### Create visualisations and identify possible monthly and seasonal trends in the data.

# %%
# Import the necessary libraries.
import seaborn as sns
import matplotlib.pyplot as plt

# Set figure size.
sns.set(rc={'figure.figsize':(15, 12)})

# Set the plot style as white.
sns.set_style('white')

# %% [markdown]
# ### Appointments Per Month

# %% [markdown]
# ### Objective 1
# Create three visualisations indicating the number of appointments per month for service settings, context types, and national categories.

# %%
# Change the data type of the appointment month to string to allow for easier plotting.
nc = nc.astype({"appointment_month": str})

# %%
# Aggregate on monthly level and determine the sum of records per month.
nc_ss = nc[['service_setting','appointment_month','count_of_appointments']]
nc_ss_sum = nc_ss.groupby(['appointment_month', 'service_setting'])[['count_of_appointments']].sum().reset_index()

# View output.
nc_ss_sum
# Out:
#    appointment_month            service_setting  count_of_appointments
# 0            2021-08  Extended Access Provision                 160927
# 1            2021-08           General Practice               21575852
# 2            2021-08                      Other                 449101
# 3            2021-08       Primary Care Network                 432448
# 4            2021-08                   Unmapped                1233843
# 5            2021-09  Extended Access Provision                 187906
# 6            2021-09           General Practice               25940821
# 7            2021-09                      Other                 527174
# 8            2021-09       Primary Care Network                 530485
# 9            2021-09                   Unmapped                1336115
# 10           2021-10  Extended Access Provision                 209539
# 11           2021-10           General Practice               27606171
# ...

# %% [markdown]
# **Service settings:**

# %%
# Plot the appointments over the available date range, and review the service settings for months.
# Create a lineplot.
APM_SS = sns.lineplot(x='appointment_month', y='count_of_appointments', data=nc_ss_sum, 
                      hue = 'service_setting', ci = None).set(title='Appt Month Serv Sett')

# Save the Plot
plt.savefig('overall appt month SS.png')

# %% [markdown]
# **Context types:**

# %%
# Create a separate data set that can be used in future weeks. 
nc_ct = nc[['context_type','appointment_month','count_of_appointments']]
nc_ct_sum = nc_ct.groupby(['appointment_month','context_type'])[['count_of_appointments']].sum().reset_index()

# View output.
nc_ct_sum
# Out:
#    appointment_month            context_type  count_of_appointments
# 0            2021-08  Care Related Encounter               20255235
# 1            2021-08    Inconsistent Mapping                2363093
# 2            2021-08                Unmapped                1233843
# 3            2021-09  Care Related Encounter               24404251
# 4            2021-09    Inconsistent Mapping                2782135
# 5            2021-09                Unmapped                1336115
# 6            2021-10  Care Related Encounter               26125201
# 7            2021-10    Inconsistent Mapping                2811977
# 8            2021-10                Unmapped                1366656
# 9            2021-11  Care Related Encounter               26282778
# 10           2021-11    Inconsistent Mapping                2865796
# 11           2021-11                Unmapped                1256496
# 12           2021-12  Care Related Encounter               21798612
# ...

# %%
# Plot the appointments over the available date range, and review the context types for months.
# Create a lineplot.
APM_CT = sns.lineplot(x='appointment_month', y='count_of_appointments', data=nc_ct_sum, 
                      hue = 'context_type', ci = None).set(title='Appointments Per Month (Context Type)')

# Save the Plot
plt.savefig('overall appt month CT.png')

# %% [markdown]
# **National categories:**

# %%
# Create a separate data set that can be used in future weeks. 
nc_nc = nc[['national_category','appointment_month','count_of_appointments']]
nc_nc_sum = nc_nc.groupby(['appointment_month','national_category'])[['count_of_appointments']].sum().reset_index()

# View output.
nc_nc_sum
# Out:
#     appointment_month                                  national_category  \
# 0             2021-08  Care Home Needs Assessment & Personalised Care...
# 1             2021-08                                    Care Home Visit
# 2             2021-08                                    Clinical Triage
# 3             2021-08                         General Consultation Acute
# 4             2021-08                       General Consultation Routine
# ..                ...                                                ...
# 193           2022-06                         Social Prescribing Service
# 194           2022-06                       Structured Medication Review
# 195           2022-06                                           Unmapped
# 196           2022-06                        Unplanned Clinical Activity
# 197           2022-06                                            Walk-in
#
#      count_of_appointments
# 0                    29676
# 1                    47583
# ...

# %%
# Plot the appointments over the available date range, and review the national categories for months.
# Create a lineplot.
APM_NC = sns.lineplot(x='appointment_month', y='count_of_appointments', data=nc_nc_sum, 
                      hue = 'national_category', ci = None).set(title = 'Appointments Per Month (Nat Cat)')

plt.legend(fontsize='xx-small', title_fontsize='40',loc = 'upper right')

# Save the Plot
plt.savefig('overall appt month NC.png')

# %% [markdown]
# ### Objective 2
# Create four visualisations indicating the number of appointments for service setting per season. The seasons are summer (August 2021), autumn (October 2021), winter (January 2022), and spring (April 2022).

# %% [markdown]
# **Summer (August 2021):**

# %%
# Create a separate data set that can be used in future weeks. 
nc_ss_ad_coa = nc[['service_setting','appointment_date','count_of_appointments']]
nc_summer = nc_ss_ad_coa[(nc_ss_ad_coa['appointment_date'] >= '2021-08-01')                                    
                         & (nc_ss_ad_coa['appointment_date'] <= '2021-08-31')]

nc_summer_sum = nc_summer.groupby(['appointment_date','service_setting'])[['count_of_appointments']].sum().reset_index()

# View output.
nc_summer_sum
# Out:
#     appointment_date            service_setting  count_of_appointments
# 0         2021-08-01  Extended Access Provision                    438
# 1         2021-08-01           General Practice                   3411
# 2         2021-08-01                      Other                    401
# 3         2021-08-01       Primary Care Network                    323
# 4         2021-08-01                   Unmapped                   1054
# ..               ...                        ...                    ...
# 150       2021-08-31  Extended Access Provision                   8281
# 151       2021-08-31           General Practice                1125584
# 152       2021-08-31                      Other                  23181
# 153       2021-08-31       Primary Care Network                  21789
# 154       2021-08-31                   Unmapped                  62380
#
# [155 rows x 3 columns]

# %%
# Look at August 2021 in more detail to allow a closer look.
# Create a lineplot.
aug_ss = sns.lineplot(x='appointment_date', y='count_of_appointments', data=nc_summer_sum, 
                      hue = 'service_setting', ci = None).set(title = 'Summer Appointments (Serv_Sett)')
plt.legend(loc = 'upper right')

# save plot.
plt.savefig('Summer SS.png')

# %% [markdown]
# **Autumn (October 2021):**

# %%
# Create a separate data set that can be used in future weeks. 
nc_autumn = nc_ss_ad_coa[(nc_ss_ad_coa['appointment_date'] >= '2021-10-01')                                    
                         & (nc_ss_ad_coa['appointment_date'] <= '2021-10-31')]

nc_autumn_sum = nc_autumn.groupby(['appointment_date','service_setting'])[['count_of_appointments']].sum().reset_index()

# View output.
nc_autumn_sum
# Out:
#     appointment_date            service_setting  count_of_appointments
# 0         2021-10-01  Extended Access Provision                   7107
# 1         2021-10-01           General Practice                1130646
# 2         2021-10-01                      Other                  22639
# 3         2021-10-01       Primary Care Network                  22974
# 4         2021-10-01                   Unmapped                  56201
# ..               ...                        ...                    ...
# 150       2021-10-31  Extended Access Provision                   1113
# 151       2021-10-31           General Practice                  17449
# 152       2021-10-31                      Other                   1147
# 153       2021-10-31       Primary Care Network                   1200
# 154       2021-10-31                   Unmapped                   2863
#
# [155 rows x 3 columns]

# %%
# Look at October 2021 in more detail to allow a closer look.
# Create a lineplot.
autumn_ss = sns.lineplot(x='appointment_date', y='count_of_appointments', data=nc_autumn_sum, color = 'red',
                         hue = 'service_setting', ci = None).set(title='Autumn Appointments (Serv_Sett)')
plt.legend(loc = 'upper right')

# save plot
plt.savefig('Autumn SS.png')

# %% [markdown]
# **Winter (January 2021):**

# %%
# Create a separate data set that can be used in future weeks. 
nc_winter = nc_ss_ad_coa[(nc_ss_ad_coa['appointment_date'] >= '2022-01-01')                                    
                         & (nc_ss_ad_coa['appointment_date'] <= '2022-01-31')]

nc_winter_sum = nc_winter.groupby(['appointment_date','service_setting'])[['count_of_appointments']].sum().reset_index()

# View output.
nc_winter_sum
# Out:
#     appointment_date            service_setting  count_of_appointments
# 0         2022-01-01  Extended Access Provision                    246
# 1         2022-01-01           General Practice                   3578
# 2         2022-01-01                      Other                    280
# 3         2022-01-01       Primary Care Network                    215
# 4         2022-01-01                   Unmapped                    572
# ..               ...                        ...                    ...
# 150       2022-01-31  Extended Access Provision                   9962
# 151       2022-01-31           General Practice                1305082
# 152       2022-01-31                      Other                  25034
# 153       2022-01-31       Primary Care Network                  30509
# 154       2022-01-31                   Unmapped                  43240
#
# [155 rows x 3 columns]

# %%
# Look at January 2022 in more detail to allow a closer look.
# Create a lineplot.
winter_ss = sns.lineplot(x='appointment_date', y='count_of_appointments', data=nc_winter_sum, color = 'y',
                         hue = 'service_setting', ci = None).set(title = 'Winter Appointment (Serv_Sett)')
plt.legend(loc = 'upper right')

# save plot
plt.savefig('winter_ss.png')

# %% [markdown]
# **Spring (April 2022):**

# %%
# Create a separate data set that can be used in future weeks. 
nc_spring = nc_ss_ad_coa[(nc_ss_ad_coa['appointment_date'] >= '2022-04-01')                                    
                         & (nc_ss_ad_coa['appointment_date'] <= '2022-04-30')]

nc_spring_sum = nc_spring.groupby(['appointment_date','service_setting'])[['count_of_appointments']].sum().reset_index()

# View output.
nc_spring_sum
# Out:
#     appointment_date            service_setting  count_of_appointments
# 0         2022-04-01  Extended Access Provision                   8011
# 1         2022-04-01           General Practice                1085037
# 2         2022-04-01                      Other                  21077
# 3         2022-04-01       Primary Care Network                  26493
# 4         2022-04-01                   Unmapped                  36836
# ..               ...                        ...                    ...
# 145       2022-04-30  Extended Access Provision                   3416
# 146       2022-04-30           General Practice                  23675
# 147       2022-04-30                      Other                   1148
# 148       2022-04-30       Primary Care Network                   3150
# 149       2022-04-30                   Unmapped                   1844
#
# [150 rows x 3 columns]

# %%
# Look at April 2022 in more detail to allow a closer look.
# Create a lineplot.
spring_ss = sns.lineplot(x='appointment_date', y='count_of_appointments', data=nc_spring_sum, color = 'magenta', 
                         hue = 'service_setting', ci = None).set(title = 'Spring Appointments (Serv_Sett)')
plt.legend(loc = 'upper right')

# save plot.
plt.savefig('spring_ss.png')

# %% [markdown]
# #

# %% [markdown]
# # Assignment activity 5

# %% [markdown]
# ### Analyse tweets from Twitter with hashtags related to healthcare in the UK.

# %%
# Libraries and settings needed for analysis
import pandas as pd
import seaborn as sns

# Set figure size.
sns.set(rc={'figure.figsize':(15, 12)})

# Set the plot style as white.
sns.set_style('white')

# Maximum column width to display
pd.options.display.max_colwidth = 200

# %%
# Load the data set.
tweets = pd.read_csv('tweets.csv')

# View the DataFrame.
tweets
# Out:
#                  tweet_id  \
# 0     1567629223795527681
# 1     1567582846612553728
# 2     1567582787070304256
# 3     1567582767625428992
# 4     1567582720460570625
# ...                   ...
# 1169  1567583004209332227
# 1170  1567582945342267393
# 1171  1567582936014241792
# 1172  1567582892892782592
# 1173  1567582846847533058
#
#                                                                                                                                                                                               tweet_full_text  \
# 0     As Arkansas’ first Comprehensive Stroke Certified Center, UAMS provides Arkansans with access to the most advanced stoke care. Join us in our mission to make a difference in the health and well-be...
# 1                                                                 RT @AndreaGrammer: Work-life balance is at the foundation of how decisions are made and where #PremiseHealth is headed.  We're #hiring for…
# ...

# %%
# Explore the metadata.
tweets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1174 entries, 0 to 1173
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   tweet_id                 1174 non-null   int64
#  1   tweet_full_text          1174 non-null   object
#  2   tweet_entities           1174 non-null   object
#  3   tweet_entities_hashtags  1007 non-null   object
#  4   tweet_metadata           1174 non-null   object
#  5   tweet_retweet_count      1174 non-null   int64
#  6   tweet_favorite_count     1174 non-null   int64
#  7   tweet_favorited          1174 non-null   bool
#  8   tweet_retweeted          1174 non-null   bool
#  9   tweet_lang               1174 non-null   object
# dtypes: bool(2), int64(3), object(5)
# memory usage: 75.8+ KB

# %%
# Explore the summary statistics
tweets.describe()
# Out:
#            tweet_id  tweet_retweet_count  tweet_favorite_count
# count  1.174000e+03          1174.000000            1174.00000
# mean   1.567612e+18             8.629472               0.37138
# std    2.427553e+13            29.784675               2.04470
# min    1.567574e+18             0.000000               0.00000
# 25%    1.567590e+18             0.000000               0.00000
# 50%    1.567611e+18             1.000000               0.00000
# 75%    1.567633e+18             3.000000               0.00000
# max    1.567655e+18           303.000000              42.00000

# %%
# Explore the data set by obtaining value counts for tweet_retweet_count
ret_count = tweets['tweet_retweet_count'].value_counts()

# Explore the data set by obtaining value counts for tweet_favorite_count.
fav_count = tweets['tweet_favorite_count'].value_counts()

# %%
# Convert ret_count series to DataFrame.
ret_count_data = pd.DataFrame(ret_count).reset_index()

# Rename ret_count DataFrame columns.
ret_count_data.rename(columns={'index': 'Retweet Count', 'tweet_retweet_count':'Number of Tweets'}, inplace=True)

# View Output
ret_count_data
# Out:
#     Retweet Count  Number of Tweets
# 0               0               526
# 1               1               215
# 2               2               114
# 3               3                70
# 4               5                35
# 5               4                27
# 6               7                18
# 7              12                16
# 8               8                15
# 9              73                14
# 10              9                13
# 11              6                12
# 12            208                12
# 13             35                10
# 14             37                 6
# 15             11                 6
# 16             10                 5
# 17             53                 5
# 18             44                 4
# 19            150                 4
# 20             63                 4
# 21             76                 3
# 22             85                 3
# 23             41                 3
# 24             62                 3
# ...

# %%
# Convert fav_count series to DataFrame.
fav_count_data = pd.DataFrame(fav_count).reset_index()

# Rename ret_count DataFrame columns.
fav_count_data.rename(columns={'index': 'Fav Count', 'tweet_favorite_count':'Number of Tweets'}, inplace=True)

# View Output
fav_count_data
# Out:
#     Fav Count  Number of Tweets
# 0           0              1027
# 1           1                91
# 2           2                16
# 3           3                13
# 4           4                 7
# 5           5                 5
# 6           6                 2
# 7          17                 1
# 8          12                 1
# 9          10                 1
# 10          8                 1
# 11         13                 1
# 12         11                 1
# 13          7                 1
# 14         20                 1
# 15         28                 1
# 16         14                 1
# 17         18                 1
# 18          9                 1
# 19         42                 1

# %%
# Would it be useful to only look at retweeted and favourite tweet messages?
# Explain your answer.

# %% [markdown]
# I think it be useful to pay attention to the number of retweets a messgae may have as a post that is retweeted more is certain to have a greater level of engagement. The same concept would apply with greater favourite tweet counts as a post which is favorited more is more likely to have more resonance with consumers.

# %%
# Create a new DataFrame containing only the text.
tweets_text = pd.read_csv('tweets.csv', usecols = ['tweet_entities_hashtags'])

# View the DataFrame.
tweets_text
# Out:
#                                                                  tweet_entities_hashtags
# 0                                                                            #Healthcare
# 1                                                                #PremiseHealth, #hiring
# 2                                                                            #Healthcare
# 3                                                                                   #NEW
# 4     #blogs, #digitaltransformation, #cybersecurity, #accounting, #finance, #healthcare
# ...                                                                                  ...
# 1169                                   #Innovation, #precisionFabrication, #Microfluidic
# 1170                                                                #SKPoli, #healthcare
# 1171                                                         #webinar, #ESG, #healthcare
# ...

# %%
# Loop through the messages, and create a list of values containing the # symbol.
tags = []
for y in [x.split(' ') for x in tweets['tweet_full_text'].values]:
    for z in y:
        if '#' in z:
            # Change to lowercase.
            tags.append(z.lower())

# View Output.
tags
# Out:
# ['#healthcare',
#  '#premisehealth',
#  '#hiring',
#  '#healthcare',
#  '🚨#new:🚨',
#  'look!\n\n#blogs',
#  '#digitaltransformation',
#  '#cybersecurity',
#  '#accounting',
#  '#finance',
#  '#healthcare',
#  'https://t.co/jrgqeqdme4\n.\n#firstcoastcna',
#  '#cnaexam',
#  '#cnaexampreparation',
#  '#jacksonville',
#  '#cnatraining',
#  '#nurse',
#  '#nursing',
#  '#nurselife',
#  '#nursepractitioner',
#  '#nurseproblems',
#  '#nursingschool',
#  '#healthcare',
#  '🚨#new:🚨',
#  '#disparities.',
#  '@karahartnett\n#healthcare',
#  '#alert',
#  '#insurance',
#  '#data\nhttps://t.co/h9hlamr7p9',
#  '#healthcare',
#  '#healthcare',
#  '❤️\n\n#healthcare',
#  '#healthcare',
#  '#hcldr',
#  '#premisehealth',
#  '#hiring',
#  '#premisehealth',
#  '#hiring',
#  '#healthcare',
#  '#qualitypatientcare',
#  '#jobs',
#  '#job',
#  '#ascp2022',
#  '#ascp100.',
#  '#healthcare',
#  '#healthsecretary',
#  '#healthcare',
#  '#ai,',
#  '#sdoh,',
#  '#healthcare',
# ...

# %%
# Display the first 30 records.
tags_2 = pd.Series(tags).value_counts()
tags_2.head(30)
# Out:
# #healthcare                    716
# #health                         80
# #medicine                       41
# #ai                             40
# #job                            38
# #medical                        35
# #strategy                       30
# #pharmaceutical                 28
# #digitalhealth                  25
# #pharma                         25
# #marketing                      25
# #medtwitter                     24
# #biotech                        24
# #competitiveintelligence        24
# #meded                          23
# #vaccine                        18
# #hiring                         18
# #news                           17
# #machinelearning                17
# #technology                     17
# #coronavirus                    16
# #womeninmedicine                16
# #covid                          16
# #competitivemarketing           16
# #wellness                       15
# #healthtech                     15
# #doctorofveterinarymedicine     14
# ...

# %%
# Convert the series to a DataFrame in preparation for visualisation.
tags_2_data = pd.DataFrame(tags_2, columns = ['twitter']).reset_index()

# Rename the columns of tags_2_data
tags_2_data.rename(columns={'twitter': 'Count', 'index':'Word'}, inplace=True)

# View Output
tags_2_data
# Out:
#                Word  Count
# 0       #healthcare    716
# 1           #health     80
# 2         #medicine     41
# 3               #ai     40
# 4              #job     38
# ...             ...    ...
# 1749      #evestudy      1
# 1750  #patientdata…      1
# 1751        #secure      1
# 1752           #sms      1
# 1753       \n#csjmu      1
#
# [1754 rows x 2 columns]

# %%
# View the Data Types
tags_2_data.dtypes
# Out:
# Word     object
# Count     int64
# dtype: object

# %%
# Display records where the count is larger than 10.
tags_3_data = tags_2_data[(tags_2_data['Count'] > 10)]

# View Output
tags_3_data
# Out:
#                            Word  Count
# 0                   #healthcare    716
# 1                       #health     80
# 2                     #medicine     41
# 3                           #ai     40
# 4                          #job     38
# 5                      #medical     35
# 6                     #strategy     30
# 7               #pharmaceutical     28
# 8                #digitalhealth     25
# 9                       #pharma     25
# 10                   #marketing     25
# 11                  #medtwitter     24
# 12                     #biotech     24
# 13     #competitiveintelligence     24
# 14                       #meded     23
# 15                     #vaccine     18
# 16                      #hiring     18
# 17                        #news     17
# 18             #machinelearning     17
# 19                  #technology     17
# 20                 #coronavirus     16
# 21             #womeninmedicine     16
# 22                       #covid     16
# ...

# %%
# Create a Seaborn barplot indicating records with a count >10 records.
# Create the plot.
tags_bar_all = sns.barplot(x='Word', y='Count', data=tags_3_data).set(title= 'Tags (all) Bar')

# View the barplot.
plt.savefig('tags bar all.png')

# %%
# Find the over - represented tags.
tags_outliers = sns.boxplot(y = 'Count', data=tags_3_data).set(title=' Outlier Analysis') 

# View Output
plt.savefig('tags_outlier_analysis.png')

# %%
# Remove over - represented 
tags_4_data = tags_3_data.drop(tags_3_data.index[[0, 1, 2]]).reset_index()
tags_5_data = tags_4_data.drop("index", axis=1)

# View Output.
tags_5_data
# Out:
#                            Word  Count
# 0                           #ai     40
# 1                          #job     38
# 2                      #medical     35
# 3                     #strategy     30
# 4               #pharmaceutical     28
# 5                #digitalhealth     25
# 6                       #pharma     25
# 7                    #marketing     25
# 8                   #medtwitter     24
# 9                      #biotech     24
# 10     #competitiveintelligence     24
# 11                       #meded     23
# 12                     #vaccine     18
# 13                      #hiring     18
# 14                        #news     17
# 15             #machinelearning     17
# 16                  #technology     17
# 17                 #coronavirus     16
# 18             #womeninmedicine     16
# 19                       #covid     16
# 20        #competitivemarketing     16
# 21                    #wellness     15
# 22                  #healthtech     15
# ...

# %%
# Plot a bar plot omiting the over represented data values
no_outliers_tag_bar = sns.barplot(x='Word', y='Count', data=tags_5_data).set(title='Tags (no outliers) Bar')

# View Output.
plt.savefig('no_outliers_tag_bar.png')

# %% [markdown]
# #

# %% [markdown]
# # Assignment activity 6

# %% [markdown]
# ### Investigate the main cencerns posed by the NHS.

# %%
# Prepare your workstation.
# Load the appointments_regional.csv file.
# View the DataFrame.
ar
# Out:
#        icb_ons_code appointment_month appointment_status hcp_type  \
# 0         E54000034           2020-01           Attended       GP
# 1         E54000034           2020-01           Attended       GP
# 2         E54000034           2020-01           Attended       GP
# 3         E54000034           2020-01           Attended       GP
# 4         E54000034           2020-01           Attended       GP
# ...             ...               ...                ...      ...
# 596816    E54000050           2022-06            Unknown  Unknown
# 596817    E54000050           2022-06            Unknown  Unknown
# 596818    E54000050           2022-06            Unknown  Unknown
# 596819    E54000050           2022-06            Unknown  Unknown
# 596820    E54000050           2022-06            Unknown  Unknown
#
#        appointment_mode time_between_book_and_appointment  \
# 0          Face-to-Face                             1 Day
# ...

# %%
# Print the min and max dates.
print('ar min:',ar['appointment_month'].min())
print('ar max:',ar['appointment_month'].max())
# Out:
# ar min: 2020-01
# ar max: 2022-06

# %%
# Filter the data set to only look at data from 2021-08 onwards.
ar_filter = ar.loc[ar['appointment_month'] >= '2021-08']

# View Output
ar_filter
# Out:
#        icb_ons_code appointment_month appointment_status hcp_type  \
# 3652      E54000034           2021-08           Attended       GP
# 3653      E54000034           2021-08           Attended       GP
# 3654      E54000034           2021-08           Attended       GP
# 3655      E54000034           2021-08           Attended       GP
# 3656      E54000034           2021-08           Attended       GP
# ...             ...               ...                ...      ...
# 596816    E54000050           2022-06            Unknown  Unknown
# 596817    E54000050           2022-06            Unknown  Unknown
# 596818    E54000050           2022-06            Unknown  Unknown
# 596819    E54000050           2022-06            Unknown  Unknown
# 596820    E54000050           2022-06            Unknown  Unknown
#
#        appointment_mode time_between_book_and_appointment  \
# 3652       Face-to-Face                             1 Day
# ...

# %% [markdown]
# **Question 1:** Should the NHS start looking at increasing staff levels?

# %%
# Create an aggregated data set to review the different features.
ar_agg = ar_filter[['appointment_month','hcp_type','appointment_status','appointment_mode',
                    'time_between_book_and_appointment', 'count_of_appointments']] 

# View the DataFrame.
ar_agg
# Out:
#        appointment_month hcp_type appointment_status appointment_mode  \
# 3652             2021-08       GP           Attended     Face-to-Face
# 3653             2021-08       GP           Attended     Face-to-Face
# 3654             2021-08       GP           Attended     Face-to-Face
# 3655             2021-08       GP           Attended     Face-to-Face
# 3656             2021-08       GP           Attended     Face-to-Face
# ...                  ...      ...                ...              ...
# 596816           2022-06  Unknown            Unknown          Unknown
# 596817           2022-06  Unknown            Unknown          Unknown
# 596818           2022-06  Unknown            Unknown          Unknown
# 596819           2022-06  Unknown            Unknown          Unknown
# 596820           2022-06  Unknown            Unknown          Unknown
#
#        time_between_book_and_appointment  count_of_appointments
# ...

# %%
# Determine the total number of appointments per month.
ar_df = ar_agg.groupby(['appointment_month'])[['count_of_appointments']].sum().reset_index()

# View Output
ar_df
# Out:
#    appointment_month  count_of_appointments
# 0            2021-08               23852171
# 1            2021-09               28522501
# 2            2021-10               30303834
# 3            2021-11               30405070
# 4            2021-12               25140776
# 5            2022-01               25635474
# 6            2022-02               25355260
# 7            2022-03               29595038
# 8            2022-04               23913060
# 9            2022-05               27495508
# 10           2022-06               25828078

# %%
# Add a new column to indicate the average utilisation of services.
# Monthly aggregate / 30 to get to a daily value.
ar_df['utilisation'] = round(ar_df.count_of_appointments/30, 1)

# View the DataFrame.
ar_df
# Out:
#    appointment_month  count_of_appointments  utilisation
# 0            2021-08               23852171     795072.4
# 1            2021-09               28522501     950750.0
# 2            2021-10               30303834    1010127.8
# 3            2021-11               30405070    1013502.3
# 4            2021-12               25140776     838025.9
# 5            2022-01               25635474     854515.8
# 6            2022-02               25355260     845175.3
# 7            2022-03               29595038     986501.3
# 8            2022-04               23913060     797102.0
# 9            2022-05               27495508     916516.9
# 10           2022-06               25828078     860935.9

# %%
# Plot sum of count of monthly visits.
# Convert the appointment_month to string data type for ease of visualisation.
ar_df = ar_df.astype({"appointment_month": str})
MV = sns.lineplot(x='appointment_month', y='count_of_appointments', data=ar_df, ci = None)\
                 .set(title = 'Monthly Visits')

# Create a lineplot with Seaborn.
MV
# Out:
# [Text(0.5, 1.0, 'Monthly Visits')]

# %%
# Plot monthly capacity utilisation.
utilise = sns.lineplot(x='appointment_month', y='utilisation', data=ar_df, ci = None)\
                  .set(title = 'Monthly Utilisation')

# Create a lineplot.
plt.savefig('utilise.png')

# %% [markdown]
# **Question 2:** How do the healthcare professional types differ over time?

# %%
# Create a line plot to answer the question.
HCP_Time = sns.lineplot(x='appointment_month', y='count_of_appointments', hue = 'hcp_type',
                        data=ar_agg, ci = None).set(title = 'HCP Variation Over Time')

# View Plot
HCP_Time
# Out:
# [Text(0.5, 1.0, 'HCP Variation Over Time')]

# %% [markdown]
# **Question 3:** Are there significant changes in whether or not visits are attended?

# %%
# Create a line plot to answer the question.
Attendance_Changes = sns.lineplot(x='appointment_month', y='count_of_appointments', hue = 'appointment_status',
                                  data=ar_agg, ci = None).set(title = 'Attendance Variation')

# Save Plot
plt.savefig('Attendance_Changes.png')

# %% [markdown]
# **Question 4:** Are there changes in terms of appointment type and the busiest months?

# %%
# Create a line plot to answer the question.
Appt_Type_Changes = sns.lineplot(x='appointment_month', y='count_of_appointments', hue = 'appointment_mode',
                                 data=ar_agg, ci = None).set(title = 'Monthly Appointment Mode Changes')

# Save plot.
plt.savefig('Appt_Type_Changes.png')

# %% [markdown]
# **Question 5:** Are there any trends in time between booking an appointment?

# %%
# Create a line plot to answer the question.
Appt_Time_Between = sns.lineplot(x='appointment_month', y='count_of_appointments', 
                                 hue = 'time_between_book_and_appointment',
                                 data=ar_agg, ci = None).set(title = 'Time Between Appt Bookings Monthly Trends')

plt.legend(fontsize = 'xx-small',loc = 'upper left')

# View Output
plt.savefig('Appt_Time_Between.png')

# %% [markdown]
# **Question 6:** How do the spread of service settings compare?

# %%
# Let's go back to the national category DataFrame you created in an earlier assignment activity.
nc
# Out:
#        appointment_date icb_ons_code  \
# 0            2021-08-02    E54000050
# 1            2021-08-02    E54000050
# 2            2021-08-02    E54000050
# 3            2021-08-02    E54000050
# 4            2021-08-02    E54000050
# ...                 ...          ...
# 817389       2022-06-30    E54000054
# 817390       2022-06-30    E54000054
# 817391       2022-06-30    E54000054
# 817392       2022-06-30    E54000054
# 817393       2022-06-30    E54000054
#
#                              sub_icb_location_name            service_setting  \
# 0       NHS North East and North Cumbria ICB - 00L       Primary Care Network
# 1       NHS North East and North Cumbria ICB - 00L                      Other
# 2       NHS North East and North Cumbria ICB - 00L           General Practice
# 3       NHS North East and North Cumbria ICB - 00L           General Practice
# 4       NHS North East and North Cumbria ICB - 00L           General Practice
# ...

# %%
# Create a new DataFrame consisting of the month of appointment,number of appointments and service settings.
nc_agg = nc[['appointment_month','count_of_appointments','service_setting']]
nc_ss_spread = nc_agg.groupby(['appointment_month', 'service_setting'])[['count_of_appointments']].sum().reset_index()


# View the DataFrame.
nc_ss_spread
# Out:
#    appointment_month            service_setting  count_of_appointments
# 0            2021-08  Extended Access Provision                 160927
# 1            2021-08           General Practice               21575852
# 2            2021-08                      Other                 449101
# 3            2021-08       Primary Care Network                 432448
# 4            2021-08                   Unmapped                1233843
# 5            2021-09  Extended Access Provision                 187906
# 6            2021-09           General Practice               25940821
# 7            2021-09                      Other                 527174
# 8            2021-09       Primary Care Network                 530485
# 9            2021-09                   Unmapped                1336115
# 10           2021-10  Extended Access Provision                 209539
# 11           2021-10           General Practice               27606171
# ...

# %%
# Create a boxplot to investigate spread of service settings.
ss_spread = sns.boxplot(data=nc_ss_spread, x='service_setting', y='count_of_appointments')\
                       .set(title = 'service setting spread')

# View Output
ss_spread
# Out:
# [Text(0.5, 1.0, 'service setting spread')]

# %%
# Remove GP from service settings DataFrame
nc_ss_spread_2 = nc_ss_spread.drop(nc_ss_spread.index[[1, 6, 11, 16, 21, 26, 31, 36, 41, 46, 51]]).reset_index()
nc_ss_spread_3 = nc_ss_spread_2.drop("index", axis=1)

# View Output.
nc_ss_spread_3
# Out:
#    appointment_month            service_setting  count_of_appointments
# 0            2021-08  Extended Access Provision                 160927
# 1            2021-08                      Other                 449101
# 2            2021-08       Primary Care Network                 432448
# 3            2021-08                   Unmapped                1233843
# 4            2021-09  Extended Access Provision                 187906
# 5            2021-09                      Other                 527174
# 6            2021-09       Primary Care Network                 530485
# 7            2021-09                   Unmapped                1336115
# 8            2021-10  Extended Access Provision                 209539
# 9            2021-10                      Other                 556487
# 10           2021-10       Primary Care Network                 564981
# 11           2021-10                   Unmapped                1366656
# ...

# %%
# Create a boxplot to investigate the service settings without GP.
ss_spread_no_gp = sns.boxplot(data=nc_ss_spread_3, x='service_setting', y='count_of_appointments')\
                       .set(title = 'service setting spread without GP')

# View Output
ss_spread_no_gp
# Out:
# [Text(0.5, 1.0, 'service setting spread without GP')]

# %% [markdown]
# #

# %% [markdown]
# ### Provide a summary of your findings and recommendations based on the analysis.

# %% [markdown]
# The maximum utilisation is 1.014e6, with the minimum utilisation being 0.795e6 .The maximum capcity is 1.2e6. Since 1.014e6 < 1.2e6, the maximum daily capacity is never exceeded. Therefore, the NHS doesn't need to increase staff levels
#
# General Practice is a service setting that requires the greatest attention as this service setting is far more greatly used compared to other service settings. Extended Access Provision, on the other hand could be ignored as very there are substatially fewer appointments for it compared to 'other', 'primary care network' and 'unmapped'
#
# For time between bookings, a signifiant number of people only book 14 days or earlier, with people preferring to book on the same day. The least bookings tend to be made during December - February, whilst the most bookings are made during September - November 2021, except for same day bookings which has its max value in March 2022
#
# For the appointment modes, only 'face-to-face' and 'telephone' appointments are significantly required.As a result all other modes essentially have a requirement that is approximately constant, depicted by the almost flat line for all 3. 'face to face' appointments notably increases in September 2021, October 2021 and Februrary 2021 with there being notable decreases in December 2021 and April 2022, whilst the value remained realtively stagnant between Decmber 2021 and February 2021 for 'face - to - face. For 'telephone' appointments, there were constant fluctuations, with the only noteable decrease being in April 2022.
#
# For Attendance, a significant proportion of people attend appointment, with the number of 'unknown' or 'DNA' being trivial compared to those that attended, and relatively constant. The number of people that attend  increases from august 2021 until november 2021, with a significant rise occuring in september 2021. The attended appointments number then markedly decreases in december 2021 before remaining realtively stagnant from december 2021 to February 2022. the increase or decrease in attended appointment then alternated, starting with an increase in March 2022. Since 'unknown' or 'DNA' remained relatively constant, it can be assumed that any fluctuations in the attended line plot was due to a fluctuation in the number of appointments booked.
